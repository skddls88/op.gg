# %%
import requests
import json

# %%
api_key = 'RGAPI-e631665d-02b9-4daf-8020-c01219f99805'

def summoner_data(nick_name):

    url = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/'+nick_name

    my_header = {
        "Origin": "https://developer.riotgames.com",
        "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
        "X-Riot-Token": api_key,
        "Accept-Language": "ko,en-US;q=0.9,en;q=0.8,ko-KR;q=0.7,zh-CN;q=0.6,zh;q=0.5",
        "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36"
    }
    req = requests.get(url=url, headers=my_header)
    json_data = json.loads(req.text)
    user_id = json_data['id']
    user_accountId = json_data['accountId']
    user_puuid = json_data['puuid']
    user_nickname = json_data['name']
    user_icon = json_data['profileIconId']
    user_level = json_data['summonerLevel']
    
    return {'user_id':user_id, 'user_accountId': user_accountId, 
           'user_puuid' : user_puuid, 'user_nickname': user_nickname,
           'user_icon': user_icon, 'user_level' : user_level}

# %%
user_data = summoner_data('hide on bush')

# %%
user_data
# Out:
# {'user_id': 'aNyo-el383FiN7IFuYyNmqeM7s39t_fAlCL3r-jE19c9Ug',
#  'user_accountId': '2_zKdOkFAQHNoJDeH-xdkuz1ia7LqSpHg47h89EeIYFl',
#  'user_puuid': 'ptcSAkrHVu2_2yLFq-efo8AV6cgCnvV-sd1rBhbB3_LWOlz_zF7Hgr8WYrT9QZai20wzQb7Oz_KI-Q',
#  'user_nickname': 'Hide on bush',
#  'user_icon': 6,
#  'user_level': 270}
